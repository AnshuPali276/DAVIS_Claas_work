# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/functionToSimpleInterest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# function to calculate simple interest
def calculateSi(p,r,t):
  return((p*r*t)/100)
#-----------------
#Main program
principle=float(input("Enter principle(in rs):"))
rate=float(input("Enter principle(in %):"))
time=int(input("Enter principle(in year):"))
print("Simple Interest:Rs",calculateSi(principle,rate,time))
# Out:
# Enter principle(in rs):20000
# Enter principle(in %):5
# Enter principle(in year):4
# Simple Interest:Rs 4000.0
