# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/ConverListToTuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# convert list to tuple
nums = list(map(int, input("Enter numbers: ").split()))

# convert list to tuple
t = tuple(nums)

print(t)
# Out:
# Enter numbers: 1034 22002 3449 2
# (1034, 22002, 3449, 2)
