# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/TotalBillAmount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Total Bill Amount
def total_bill(items):
    total = 0
    for price in items:
        total += price  # add all prices
    return total

nums = list(map(int, input("Enter prices: ").split()))
print("Total =", total_bill(nums))
# Out:
# Enter prices: 1000 3000 4000 2000 100
# Total = 10100
