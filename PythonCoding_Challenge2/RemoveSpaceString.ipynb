# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/RemoveSpaceString.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Remove Space From String
text = input("Enter string: ")

result = ""

for ch in text:
    # skip space
    if ch != " ":
        result += ch

print(result)
# Out:
# Enter string: Welcome To Home
# WelcomeToHome
