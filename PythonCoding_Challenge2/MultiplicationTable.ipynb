# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/MultiplicationTable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Multiplication Table
n = int(input("Enter number: "))

for i in range(1, 11):
    print(n * i, end=" ")
# Out:
# Enter number: 5
# 5 10 15 20 25 30 35 40 45 50
