# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/RemoveDuplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# remove duplicate from list
nums = list(map(int, input("Enter numbers: ").split()))

result = []

for i in nums:
    # add only if not already present
    if i not in result:
        result.append(i)

print(result)
# Out:
# Enter numbers: 10 20 10 30 20 50 60
# [10, 20, 30, 50, 60]
