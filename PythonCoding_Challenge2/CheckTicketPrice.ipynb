# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CheckTicketPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  check Ticket Price
day = input("Enter day: ")

if day.lower() == "sunday":
    print("200")
else:
    print("150")
# Out:
# Enter day: monday
# 150
