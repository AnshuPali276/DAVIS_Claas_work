# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CountNumbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Count Numbers >50
nums = list(map(int, input("Enter numbers: ").split()))

count = 0
for i in nums:
    if i > 50:
        count += 1

print(count)
# Out:
# Enter numbers: 10 2 5 6 7 8
# 0
