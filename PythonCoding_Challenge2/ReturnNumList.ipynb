# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/ReturnNumList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# return even Number Fron list
def get_even(nums):
    even = []
    for i in nums:
        if i % 2 == 0:  # check even
            even.append(i)
    return even

nums = list(map(int, input("Enter numbers: ").split()))
print(get_even(nums))
# Out:
# Enter numbers: 10 40 30 50
# [10, 40, 30, 50]
