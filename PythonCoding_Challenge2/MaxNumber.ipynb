# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/MaxNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find Max number without Built-in function
nums = list(map(int, input("Enter numbers: ").split()))

max_num = nums[0]

for i in nums:
    if i > max_num:
        max_num = i

print("Max =", max_num)
# Out:
# Enter numbers: 13 14 15 28 45 22374 15
# Max = 22374
