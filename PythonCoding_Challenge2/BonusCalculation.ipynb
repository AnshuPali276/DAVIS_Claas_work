# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/BonusCalculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bonus calculation
salary = int(input("Enter salary: "))

if salary > 30000:
    bonus = salary * 0.07
else:
    bonus = salary * 0.05

print("Bonus =", int(bonus))
