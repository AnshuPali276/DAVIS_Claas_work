# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CountOccurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# count Occurance of character
text = input("Enter string: ")
char = input("Enter character: ")

count = 0
for ch in text:
    if ch == char:
        count += 1

print("Count =", count)
# Out:
# Enter string: welcom home
# Enter character: 1
# Count = 0
