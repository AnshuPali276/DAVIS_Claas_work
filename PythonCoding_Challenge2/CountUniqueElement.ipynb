# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CountUniqueElement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# count Unique Element
nums = list(map(int, input("Enter numbers: ").split()))

unique = []

for i in nums:
    # store only unique values
    if i not in unique:
        unique.append(i)

print("Unique count =", len(unique))
# Out:
# Enter numbers: 10 30 50
# Unique count = 3
