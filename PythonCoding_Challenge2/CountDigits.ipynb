# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CountDigits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Count Digits
num = int(input("Enter number: "))

count = 0
while num > 0:
    count += 1
    num = num // 10

print("Digits =", count)
# Out:
# Enter number: 1926364499
# Digits = 10
