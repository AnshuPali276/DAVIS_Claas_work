# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CheckAnagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check Anagram
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

# sort both strings and compare
if sorted(s1) == sorted(s2):
    print("True")
else:
    print("False")
# Out:
# Enter first string: anamika
# Enter second string: anjali
# False
