# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find Factorial
n = int(input("Enter number: "))

fact = 1
for i in range(1, n+1):
    fact *= i

print("Factorial =", fact)
# Out:
# Enter number: 5
# Factorial = 120
