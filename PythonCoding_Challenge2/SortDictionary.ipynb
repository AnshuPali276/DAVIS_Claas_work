# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/SortDictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# sort Dictionar
d = {"b": 2, "a": 1}

# sort dictionary keys
sorted_dict = {}

for key in sorted(d):
    sorted_dict[key] = d[key]

print(sorted_dict)
# Out:
# Enter numbers: 10 40 30 50
# [10, 40, 30, 50]
