# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CheckKeyInDic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check Key In dictionary
d = {"a": 1, "b": 2}

key = input("Enter key: ")

# check key existence
if key in d:
    print("Yes")
else:
    print("No")
# Out:
# Enter key: 5
# No
