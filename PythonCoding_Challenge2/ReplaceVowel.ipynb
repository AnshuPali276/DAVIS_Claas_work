# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/ReplaceVowel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Repalce vowel with *
text = input("Enter string: ")

result = ""

for ch in text:
    # replace vowel with *
    if ch.lower() in "aeiou":
        result += "*"
    else:
        result += ch

print(result)
# Out:
# Enter string: Anshu
# *nsh*
