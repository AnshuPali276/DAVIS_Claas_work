# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/Divisible3_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Divisible by 3 and 5
num = int(input("Enter number: "))

if num % 3 == 0 and num % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
# Enter number: 60
# Yes
