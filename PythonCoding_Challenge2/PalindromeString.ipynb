# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/PalindromeString.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Palindrom string
text = input("Enter string: ")

# reverse string using slicing
rev = text[::-1]

if text == rev:
    print("Yes")
else:
    print("No")
# Out:
# Enter string: KanaK
# Yes
