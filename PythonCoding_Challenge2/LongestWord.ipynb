# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/LongestWord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find longest Word
text = input("Enter sentence: ")

words = text.split()
longest = words[0]

for word in words:
    # compare lengths
    if len(word) > len(longest):
        longest = word

print("Longest word =", longest)
# Out:
# Enter sentence: ram shyan Ritika
# Longest word = Ritika
