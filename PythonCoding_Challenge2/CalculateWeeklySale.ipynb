# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CalculateWeeklySale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calculate total weekly Sales
sales = list(map(int, input("Enter 7 days sales: ").split()))

total = 0
for i in sales:
    total += i

print("Total Sales =", total)
# Out:
# Enter 7 days sales: 100 150 130 150 0 10 50
# Total Sales = 590
