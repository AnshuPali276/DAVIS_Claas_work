# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/CountVowelInString.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# count vowel in string
text = input("Enter string: ")

count = 0
for ch in text:
    # check vowel
    if ch.lower() in "aeiou":
        count += 1

print("Vowels =", count)
# Out:
# Enter string: Anshu
# Vowels = 2
