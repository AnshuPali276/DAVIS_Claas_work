# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/FreqencyOfNum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Freqency Of Elements
nums = list(map(int, input("Enter numbers: ").split()))
freq = {}
for i in nums:
    # count frequency
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1

print(freq)
# Out:
# Enter numbers: 200
# {200: 1}
