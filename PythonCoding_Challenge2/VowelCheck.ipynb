# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/PythonCoding_Challenge2/VowelCheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Vowel Check
ch = input("Enter character: ")

if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter character: c
# Consonant
