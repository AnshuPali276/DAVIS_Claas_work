# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/EvenorOdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program to calculate sum of two number:
#function to add two number
def addNumbers(x,y):
  return (x+y)
# main program
num1=int(input("Enter First Number:"))
num2=int(input("Enter Second Number:"))
print("Sum=",addNumbers(num1,num2))
# Out:
# Enter First Number:10
# Enter Second Number:30
# Sum= 40

# %%
#WAP to check a number is odd or even.
def check_even_odd(num):
  if num%2==0:
    print(num,"is even")
  else:
    print(num,"is odd")
number=int(input("Enter a number"))
# funtion calling
check_even_odd(number)
# Out:
# Enter a number20
# 20 is even
