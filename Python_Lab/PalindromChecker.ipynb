# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/Python_Lab/PalindromChecker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Palindrome Checker
def palindrome(x):
    s = str(x)
    rev = s[::-1]
    if s == rev:
        print("Palindrome")
    else:
        print("Not Palindrome")

val = input("Enter value: ")
palindrome(val)
# Out:
# Enter value: jahaj
# Palindrome
