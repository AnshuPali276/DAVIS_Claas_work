# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/Python_Lab/PatternPrinting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pattern Printing
n = int(input("Enter number of rows: "))

for i in range(1, n+1):
    if i % 2 == 0:
        print("* " * i)
    else:
        print("# " * i)
# Out:
# Enter number of rows: 5
# #
# * *
# # # #
# * * * *
# # # # # #
