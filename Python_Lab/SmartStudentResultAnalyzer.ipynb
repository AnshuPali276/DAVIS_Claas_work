# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/Python_Lab/SmartStudentResultAnalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://raw.githubusercontent.com/AnshuPali276/DAVIS_Claas_work/refs/heads/main/Python_Lab/SmartStudentResultAnalyzer.txt"

response = requests.get(url)
text = response.text

print(text)
# Out:
# #1. Smart Student Result Analyzer
# #A school stores student data in a file:
# #id,name,marks1,marks2,marks3
# #Build a system that:
# #•	Reads file
# #•	Calculates total, percentage
# #•	Assigns grade using selection statements
# #•	Handles missing/invalid data using exception handling
# #•	Outputs toppers per class
#
# # Function to calculate grade
# def get_grade(percentage):
#     if percentage >= 90:
#         return "A+"
#     elif percentage >= 75:
#         return "A"
#     elif percentage >= 60:
#         return "B"
#     elif percentage >= 50:
#         return "C"
#     else:
#         return "Fail"
#
#
# # Main program
# students = []
#
# try:
#     with open("students.txt", "r") as file:
#         next(file)  # skip header
#
#         for line in file:
#             try:
#                 data = line.strip().split(",")
#
#                 if len(data) != 5:
#                     raise ValueError("Incomplete data")
#
#                 sid, name = data[0], data[1]
#
# ...
