# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/ModulsInPython/Calculation1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculation1.py
import numericCalculation
m=10
n=20
print("sum of",m,"and",n,"is:",numericCalculation.calculateSum(m,n))
print("product of",m,"and",n,"is:",numericCalculation.calculateMul(m,n))
