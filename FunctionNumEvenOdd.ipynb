# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/FunctionNumEvenOdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Creat a function to find given no. Even or odd.
def check_even_odd(num):
    if num % 2 == 0:
        print("Even")
    else:
        print("Odd")

number = int(input("Enter a number: "))
check_even_odd(number)
