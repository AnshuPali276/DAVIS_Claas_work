# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/ReadFileByUrl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = "https://raw.githubusercontent.com/AnshuPali276/DAVIS_Claas_work/refs/heads/main/ZerosArray.txt"

import requests

response = requests.get(url)
text_data = response.text

print(text_data)
# Out:
# # array creation in numpy
# import numpy as np
# array3=np.zeros((3,5))
# print(array3)
