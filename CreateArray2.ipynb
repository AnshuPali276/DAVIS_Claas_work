# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuPali276/DAVIS_Claas_work/blob/main/CreateArray2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# to create array
data=np.array([20,29,39,46,50,60,90])
print(data)
#Dividing each element by 5
numbers2=data/2
print("After dividing each element by 5: ")
print(numbers2)
# Out:
# [20 29 39 46 50 60 90]
# After dividing each element by 5:
# [10.  14.5 19.5 23.  25.  30.  45. ]
